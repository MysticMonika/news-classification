# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt

# %%
df = pd.read_json('D:/MachineLearning/category/News_Category_Dataset.json', lines=True)
df.head()
# Out:
#            authors       category       date  \
# 0  Melissa Jeltsen          CRIME 2018-05-26
# 1    Andy McDonald  ENTERTAINMENT 2018-05-26
# 2       Ron Dicker  ENTERTAINMENT 2018-05-26
# 3       Ron Dicker  ENTERTAINMENT 2018-05-26
# 4       Ron Dicker  ENTERTAINMENT 2018-05-26
#
#                                             headline  \
# 0  There Were 2 Mass Shootings In Texas Last Week...
# 1  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2    Hugh Grant Marries For The First Time At Age 57
# 3  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4  Julianna Margulies Uses Donald Trump Poop Bags...
#
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/texas-ama...
# 1  https://www.huffingtonpost.com/entry/will-smit...
# 2  https://www.huffingtonpost.com/entry/hugh-gran...
# 3  https://www.huffingtonpost.com/entry/jim-carre...
# 4  https://www.huffingtonpost.com/entry/julianna-...
#
# ...

# %%
title = df.groupby('category')
print("total categories:", title.ngroups)
print(title.size())
# Out:
# total categories: 31
# category
# ARTS               1509
# ARTS & CULTURE     1339
# BLACK VOICES       3858
# BUSINESS           4254
# COLLEGE            1144
# COMEDY             3971
# CRIME              2893
# EDUCATION          1004
# ENTERTAINMENT     14257
# FIFTY              1401
# GOOD NEWS          1398
# GREEN              2622
# HEALTHY LIVING     6694
# IMPACT             2602
# LATINO VOICES      1129
# MEDIA              2815
# PARENTS            3955
# POLITICS          32739
# QUEER VOICES       4995
# RELIGION           2556
# SCIENCE            1381
# SPORTS             4167
# STYLE              2254
# TASTE              2096
# TECH               1231
# THE WORLDPOST      3664
# TRAVEL             2145
# WEIRD NEWS         2670
# WOMEN              3490
# WORLD NEWS         2177
# WORLDPOST          2579
# dtype: int64

# %%
df.category = df.category.map(lambda x: "WORLDPOST" if x == "THE WORLDPOST" else x)

# %%
df["combine"] = df.headline + " " + df.short_description

# %% [markdown]
# ### preprocessing data

# %%
# remove special characters, numbers, punctuations
df['combine'] = df['combine'].str.replace("[^a-zA-Z#]", " ")

# %%
df['combine'] = df['combine'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>=3]))

# %%
df.head()
# Out:
#            authors       category       date  \
# 0  Melissa Jeltsen          CRIME 2018-05-26
# 1    Andy McDonald  ENTERTAINMENT 2018-05-26
# 2       Ron Dicker  ENTERTAINMENT 2018-05-26
# 3       Ron Dicker  ENTERTAINMENT 2018-05-26
# 4       Ron Dicker  ENTERTAINMENT 2018-05-26
#
#                                             headline  \
# 0  There Were 2 Mass Shootings In Texas Last Week...
# 1  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2    Hugh Grant Marries For The First Time At Age 57
# 3  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4  Julianna Margulies Uses Donald Trump Poop Bags...
#
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/texas-ama...
# 1  https://www.huffingtonpost.com/entry/will-smit...
# 2  https://www.huffingtonpost.com/entry/hugh-gran...
# 3  https://www.huffingtonpost.com/entry/jim-carre...
# 4  https://www.huffingtonpost.com/entry/julianna-...
#
# ...

# %%
tokenized_tweet = df['combine'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0    [There, Were, Mass, Shootings, Texas, Last, We...
# 1    [Will, Smith, Joins, Diplo, Nicky, World, Offi...
# 2    [Hugh, Grant, Marries, First, Time, actor, lon...
# 3    [Carrey, Blasts, Castrato, Adam, Schiff, Democ...
# 4    [Julianna, Margulies, Uses, Donald, Trump, Poo...
# Name: combine, dtype: object

# %%
from nltk.stem.porter import*
stemmer = PorterStemmer()

tokenized_com = tokenized_tweet.apply(lambda x: [stemmer.stem(i) for i in x])
tokenized_com.head()
# Out:
# 0    [there, were, mass, shoot, texa, last, week, o...
# 1    [will, smith, join, diplo, nicki, world, offic...
# 2    [hugh, grant, marri, first, time, actor, longt...
# 3    [carrey, blast, castrato, adam, schiff, democr...
# 4    [julianna, marguli, use, donald, trump, poop, ...
# Name: combine, dtype: object

# %% [markdown]
# ### creating word cloud for some of the categories

# %%
all_words = ' '.join([text for text in df['combine']])
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
normal_words =' '.join([text for text in df['combine'][df['category'] == 'POLITICS']])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
normal_words =' '.join([text for text in df['combine'][df['category'] == 'ENTERTAINMENT']])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
normal_words =' '.join([text for text in df['combine'][df['category'] == 'BUSINESS']])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
bow_vectorizor = CountVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')

# bag-of-words feature matrix
bow = bow_vectorizor.fit_transform(df['combine'])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')

# TF-IDF feature matrix
tfidf = tfidf_vectorizer.fit_transform(df['combine'])

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn_evaluation.plot import confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer

# %%
# convert data to vectors

vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(new['TITLE'])

y = df['category']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 30% split

# fit and score the bayesian classifier
mnb = MultinomialNB(alpha=1)
mnb.fit(X_train, y_train)
mnb.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-9267e6d202bb> in <module>()
#       2
#       3 vectorizer = CountVectorizer(stop_words='english')
# ----> 4 X = vectorizer.fit_transform(news['TITLE'])
#       5
#       6 y = df['category']
#
# NameError: name 'news' is not defined
